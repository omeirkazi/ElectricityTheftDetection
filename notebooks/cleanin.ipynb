# %%
# import pandas as pd

# # -------------------------------
# # 1. Load Data
# # -------------------------------
# input_path = "../data/processed/window_features.csv"
# output_path = "../data/processed/window_features_clean.csv"

# df = pd.read_csv(input_path)

# print("Data loaded ✅")
# print("Shape (before):", df.shape)


# # -------------------------------
# # 2. Basic Check
# # -------------------------------
# print("\n--- INFO ---")
# print(df.info())

# print("\n--- HEAD ---")
# print(df.head())


# # -------------------------------
# # 3. Check zero-heavy rows
# # -------------------------------
# zero_rows = (df["mean"] == 0).sum()
# high_zero_pct = (df["zero_pct"] == 1).sum()

# print("\nRows with mean = 0:", zero_rows)
# print("Rows with zero_pct = 1:", high_zero_pct)


# # -------------------------------
# # 4. Apply Filtering (IMPORTANT)
# # -------------------------------
# valid_mask = (
#     (df["mean"] > 0.0001) &
#     (df["zero_pct"] < 0.95)
# )

# df_clean = df[valid_mask].reset_index(drop=True)


# # -------------------------------
# # 5. Stats After Cleaning
# # -------------------------------
# print("\nShape (after):", df_clean.shape)

# removed = len(df) - len(df_clean)
# print("Rows removed:", removed)

# print("\n% Data removed:", round((removed / len(df)) * 100, 2), "%")


# # -------------------------------
# # 6. Save Clean Data
# # -------------------------------
# df_clean.to_csv(output_path, index=False)

# print("\nCleaned data saved ✅ →", output_path)
# Out:
# Data loaded ✅
# Shape (before): (7299, 20)
#
# --- INFO ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7299 entries, 0 to 7298
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   meter_id         7299 non-null   object
#  1   window_id        7299 non-null   int64
#  2   mean             7299 non-null   float64
#  3   std              7299 non-null   float64
#  4   min              7299 non-null   float64
#  5   max              7299 non-null   float64
#  6   median           7299 non-null   float64
#  7   range            7299 non-null   float64
#  8   load_factor      7299 non-null   float64
#  9   peak_to_avg      7299 non-null   float64
#  10  cv               7299 non-null   float64
#  11  mean_abs_diff    7299 non-null   float64
#  12  std_diff         7299 non-null   float64
#  13  day_mean         7299 non-null   float64
#  14  night_mean       7299 non-null   float64
# ...

# %%
# print("\nShape (after):", df_clean.shape)
# Out:
# Shape (after): (6941, 20)
